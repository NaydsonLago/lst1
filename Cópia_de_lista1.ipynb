# %% [markdown]
# <a href="https://colab.research.google.com/github/NaydsonLago/lst1/blob/main/C%C3%B3pia_de_lista1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import io

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#questao 1
# importing cv2 
import cv2 
from google.colab.patches import cv2_imshow
from PIL import Image, ImageFilter
import numpy as np
import matplotlib.pyplot as plt
  
   
# Reading an image in default mode
image1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img1.jpg')
plt.subplot (1,2,1)
plt.imshow(image1)
plt.title('Defesa de Goleiro')
# Reading an image in default mode
image2 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img2.png')
plt.subplot (1,2,2)
plt.imshow(image2)
plt.title('Goku')
# Out:
# Text(0.5, 1.0, 'Goku')

# %%
#questão 2
import cv2 
from google.colab.patches import cv2_imshow
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

image1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img1.jpg')
gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
#cv2.imshow("Imagem 1 JPG escala cinza", gray1)
plt.subplot (1,2,1)
plt.imshow(gray1)
plt.title('Defesa de goleiro em esala cinza')

image2 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img2.png')
gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
#cv2.imshow("Imagem 2 JPG escala cinza", gray1)
plt.subplot (1,2,2)
plt.imshow(gray2)
plt.title('Goku em esala cinza')
# Out:
# Text(0.5, 1.0, 'Goku em esala cinza')

# %%
#questao 3
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

image1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img1.jpg')
image2 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img2.png')
dim = (1200, 800)
resized_image1 = cv2.resize(image1, dim, interpolation = cv2.INTER_AREA) #redimensionamento da imagem 1
cv2.imwrite("image1RD.jpg", resized_image1)
resized_image2 = cv2.resize(image2, dim, interpolation = cv2.INTER_AREA) #redimensionamento da imagem 2
cv2.imwrite("image2RD.png", resized_image2)
dist = cv2.addWeighted(resized_image1, 0.5, resized_image2, 0.5, 0.0) #misturando as imagens
#cv2.imshow("Imagens Misturadas", dist)
plt.imshow(dist)

# %%
#questao 4
img_ori = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Images/Fig0227(a)(washington_infrared).tif", 0)
norm_img = np.zeros((800,800))
img_ori = np.uint8(normalize(img_ori) * 255)

height, width = img_ori.shape[:2]
dst = np.zeros([height, width], dtype=np.uint8)
for h in range(height):
    for w in range(width):
        dst[h, w] = set_bin_last_0(img_ori[h, w])

dst = np.uint8(normalize(dst) * 255)
        
img_diff = img_ori - dst
img_diff = np.uint8(normalize(img_diff) * 255)

plt.figure(figsize=(24, 8))
plt.subplot(1,3,1), plt.imshow(img_ori, 'gray'), plt.title("Original"),# plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2), plt.imshow(dst, 'gray'), plt.title("Set bin last 0"),# plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3), plt.imshow(img_diff, 'gray'), plt.title("Difference"),# plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-02bceef28253> in <module>()
#       2 img_ori = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Images/Fig0227(a)(washington_infrared).tif", 0)
#       3 norm_img = np.zeros((800,800))
# ----> 4 img_ori = np.uint8(normalize(img_ori) * 255)
#       5
#       6 height, width = img_ori.shape[:2]
#
# NameError: name 'normalize' is not defined

# %%
#questao 5
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

Img_a = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/Fig0228(a)(angiography_mask_image).tif')
Img_b = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/Fig0228(b)(angiography_live_ image).tif')
subtraction = Img_a-Img_b
subimg = cv2.subtract(Img228_a, Img228_b)
#cv2.imshow("Subtração das imagens 1 jpg: original - cinza", subimg)
plt.subplot(2,3,1), plt.imshow(Img_a), plt.title("Imag_a")
plt.subplot(2,3,2), plt.imshow(Img_b), plt.title("Imag_b")
plt.subplot(2,3,3), plt.imshow(subtraction), plt.title("Img_a - Imag_b")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f9a86f3f690>,
# ...
#  Text(0.5, 1.0, 'Img_a - Imag_b'))

# %%
#questao 6
import cv2
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np
img_ori = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Images/galaxy_pair_original.tif", 0)

dst = np.zeros_like(img_ori, dtype=float)

for i in range(100):
    dst += img_ori

dst_1000 = np.zeros_like(img_ori, dtype=float)
for i in range(1000):
    dst_1000 += img_ori

plt.figure(figsize=(24, 8))
plt.subplot(2,2,1), plt.imshow(img_ori, 'gray'), plt.title("Original"),
plt.subplot(2,2,2), plt.imshow(dst, 'gray'), plt.title("10"),
plt.subplot(2,2,3), plt.imshow(dst_1000, 'gray'), plt.title("50"),
plt.subplot(2,2,4), plt.imshow(dst_1000, 'gray'), plt.title("100"),plt.tight_layout()
plt.show()

# %%
#questao 7 e 8
import cv2
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np
img_a = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Images/Fig0230(a)(dental_xray).tif", 0)
img_b = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Images/Fig0230(a)(dental_xray).tif", 0)
norm_img = np.zeros((800,800))
img_temp = cv2.normalize(img_b, norm_img)
#img_temp = normalize(img_b)
img_dst = img_a * img_temp
#img_dst = img_a * img_b
plt.figure(figsize=(18, 8))
plt.subplot(1,3,1), plt.imshow(img_a, 'gray'), plt.title("Image A")
plt.subplot(1,3,2), plt.imshow(img_b, 'gray'), plt.title("Image B")
plt.subplot(1,3,3), plt.imshow(img_dst, 'gray'), plt.title("Multiplicação duas imagens")
plt.tight_layout()
plt.show()

# %%
#questao 9
import cv2
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np

img_a = cv2.imread("/content/drive/MyDrive/Colab Notebooks/Images/Fig0232(a)(partial_body_scan).tif", 0)
img_b = 255 - img_a

img_dst = np.zeros(img_a.shape[:2], dtype=np.float)
height, width = img_a.shape[:2]
z = 3 * np.sum(img_a) / (img_a.size)
for i in range(height):
    for j in range(width):
        img_dst[i, j] = max(img_a[i, j], z)

plt.figure(figsize=(15, 10))
plt.subplot(1,3,1), plt.imshow(img_a, 'gray'), plt.title("Image A"), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2), plt.imshow(img_b, 'gray'), plt.title("Image B"), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3), plt.imshow(img_dst, 'gray'), plt.title("Calibration"), plt.xticks([]), plt.yticks([])
plt.tight_layout()
plt.show()

# %%
#questao 10
import cv2
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np

image1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img1.jpg')
image2 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img2.png')
gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
dim = (1200, 800)
resized_gray1 = cv2.resize(gray1, dim, interpolation = cv2.INTER_AREA) #redimensionamento da imagem 1
resized_gray2 = cv2.resize(gray2, dim, interpolation = cv2.INTER_AREA) #redimensionamento da imagem 2


#AND
#res = cv2.bitwise_and(image1,image2, mask= None)
dest_and = cv2.bitwise_and(resized_gray1, resized_gray2, mask=None)

#NOT
dest_not1 = cv2.bitwise_not(resized_gray1, mask = None)
dest_not2 = cv2.bitwise_not(resized_gray2, mask = None)
#cv2.imshow('Resultado da imagem 1 com NOT ', dest_not1)
#cv2.imshow('Resultado da imagem 2 com NOT', dest_not2)

plt.subplot(1,3,1), plt.imshow(dest_and), plt.title("Resultado AND")
plt.subplot(1,3,2), plt.imshow(dest_not1), plt.title("Resultado Not 1")
plt.subplot(1,3,3), plt.imshow(dest_not2), plt.title("Resultado Not 2")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f9a8771e3d0>,
# ...
#  Text(0.5, 1.0, 'Resultado Not 2'))

# %%
#questao 11

import cv2
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import numpy as np

#rotação sem interpolação

image1 = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Images/img1.jpg')
gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
(alt, lar) = gray1.shape[:2] #captura altura e largura
centro = (lar // 2, alt // 2) #acha o centro
M = cv2.getRotationMatrix2D(centro, 45, 1.0) #centro-angulo-escala
gray1_rotacionada = cv2.warpAffine(gray1, M, (lar, alt))
plt.imshow(gray1_rotacionada)

#Escala sem interpolação
gray1_redimensionada = gray1[::2 ,::2] #definição do redimensionamento

plt.subplot(1,3,1), plt.imshow(gray1), plt.title("imagem original")
plt.subplot(1,3,2), plt.imshow(gray1_rotacionada), plt.title("Rotação 45 graus")
plt.subplot(1,3,3), plt.imshow(gray1_redimensionada), plt.title("Ecala menor")
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f9a905f34d0>,
# ...
#  Text(0.5, 1.0, 'Ecala menor'))
